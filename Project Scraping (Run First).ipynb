# %% [markdown]
# ### Caeden Kropf
# ### College Attendance Project
# ### 12/12/25

# %%
import requests
from bs4 import BeautifulSoup
import time, random
import pandas as pd
import time, random
import re
from IPython.display import HTML
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from urllib.request import urlopen
from json import loads

# %% [markdown]
# ### CFB Stats Scraping

# %% [markdown]
# ##### Getting Valid Team Ids from CFB Stats for scraping

# %%
base_url = "https://cfbstats.com/2021/team"
index_url = f"{base_url}/index.html"

print("Starting scrape: conferences, teams, and average home attendance...\n")

# Step 1: Get all teams + their conferences from the index page
resp = requests.get(index_url)
soup = BeautifulSoup(resp.text, "html.parser")

conference_data = []

for conf_div in soup.find_all("div", class_="conference"):
    conf_name = conf_div.find("h1").text.strip()

    for team_link in conf_div.find_all("a"):
        team_name = team_link.text.strip()
        href = team_link["href"]  # e.g. /2024/team/721/index.html
        team_id = href.split("/")[3]  # Extract numeric team ID
        conference_data.append({
            "team_id": int(team_id),
            "team_name": team_name,
            "conference": conf_name
        })

conference_df = pd.DataFrame(conference_data)
print(f"Found {len(conference_df)} teams across {conference_df['conference'].nunique()} conferences.\n")

# Step 2: Loop through each team to get their average home attendance + record
attendance_records = []

for _, row in conference_df.iterrows():
    team_id = row["team_id"]
    team_name = row["team_name"]
    conference = row["conference"]

    team_url = f"{base_url}/{team_id}/index.html"
    print(f"Scraping {team_name} ({conference}) → {team_url}")

    try:
        resp = requests.get(team_url, timeout=10)
        if resp.status_code != 200:
            print(f"Skipping {team_name} (status {resp.status_code})")
            continue

        soup = BeautifulSoup(resp.text, "html.parser")

        # ---- A) Extract attendance from schedule table (same as before) ----
        rows = soup.select("table tr")
        home_attendances = []

        for r in rows:
            cols = [c.text.strip() for c in r.find_all("td")]
            if len(cols) >= 5:
                date, opponent, result, game_time, attendance = cols[:5]

                # Clean attendance
                attendance = attendance.replace(",", "").strip()
                attendance = int(attendance) if attendance.isdigit() else None

                # Keep home games only (no '@' or '+')
                if not opponent.startswith("@") and not opponent.startswith("+") and attendance:
                    home_attendances.append(attendance)

        avg_home = int(round(sum(home_attendances) / len(home_attendances))) if home_attendances else None

        # ---- B) Extract record from "Team Record" table (All Games row) ----
        wins, losses = None, None

        for table in soup.find_all("table"):
            found = False
            for r in table.find_all("tr"):
                cells = r.find_all("td")
                if len(cells) >= 2:
                    split_label = cells[0].get_text(strip=True)
                    if split_label == "All Games":
                        record_text = cells[1].get_text(strip=True)  # e.g. "8-4"
                        # Clean and split "8-4" or "8 - 4"
                        record_text = record_text.replace(" ", "")
                        parts = record_text.split("-")

                        if len(parts) >= 2 and parts[0].isdigit() and parts[1].isdigit():
                            wins = int(parts[0])
                            losses = int(parts[1])
                        found = True
                        break
            if found:
                break

        if wins is not None and losses is not None and (wins + losses) > 0:
            win_pct = wins / (wins + losses)
        else:
            win_pct = None

        attendance_records.append({
            "team_id": team_id,
            "team_name": team_name,
            "conference": conference,
            "wins": wins,
            "losses": losses,
            "win_pct": round(win_pct, 3) if win_pct is not None else None,
            "avg_home_attendance": avg_home,
            "num_home_games": len(home_attendances)
        })

        print(f"{team_name}: {wins}-{losses} ({round(win_pct,3) if win_pct else 'N/A'}) | "
              f"{avg_home if avg_home is not None else 'N/A'} avg over {len(home_attendances)} home games\n")

    except Exception as e:
        print(f"Error scraping {team_name}: {e}")

    time.sleep(random.uniform(2, 5))  # polite delay

# Step 3: Combine results and save
attendance_df = pd.DataFrame(attendance_records)
attendance_df = attendance_df.sort_values("avg_home_attendance", ascending=False)
attendance_df.to_csv("cfbstats_conference_attendance.csv", index=False)

print("\nScraping complete! Saved as 'cfbstats_conference_attendance.csv'")
print(f"Total teams with data: {len(attendance_df)}")
# Out:
# Starting scrape: conferences, teams, and average home attendance...
#
# Found 130 teams across 11 conferences.
#
# Scraping Cincinnati (American Athletic Conference) → https://cfbstats.com/2021/team/140/index.html
# Cincinnati: 13-1 (0.929) | 37338 avg over 7 home games
#
# Scraping East Carolina (American Athletic Conference) → https://cfbstats.com/2021/team/196/index.html
# East Carolina: 7-5 (0.583) | 36059 avg over 6 home games
#
# Scraping Houston (American Athletic Conference) → https://cfbstats.com/2021/team/288/index.html
# Houston: 12-2 (0.857) | 25073 avg over 5 home games
#
# Scraping Memphis (American Athletic Conference) → https://cfbstats.com/2021/team/404/index.html
# Memphis: 6-6 (0.5) | 31295 avg over 7 home games
#
# Scraping Navy (American Athletic Conference) → https://cfbstats.com/2021/team/726/index.html
# Navy: 4-8 (0.333) | 31094 avg over 6 home games
#
# Scraping SMU (American Athletic Conference) → https://cfbstats.com/2021/team/663/index.html
# SMU: 8-4 (0.667) | 23171 avg over 6 home games
#
# Scraping Temple (American Athletic Conference) → https://cfbstats.com/2021/team/690/index.html
# Temple: 3-9 (0.25) | 21464 avg over 6 home games
#
# Scraping Tulane (American Athletic Conference) → https://cfbstats.com/2021/team/718/index.html
# Tulane: 2-10 (0.167) | 14574 avg over 6 home games
#
# Scraping Tulsa (American Athletic Conference) → https://cfbstats.com/2021/team/719/index.html
# Tulsa: 7-6 (0.538) | 16076 avg over 6 home games
#
# Scraping UCF (American Athletic Conference) → https://cfbstats.com/2021/team/128/index.html
# UCF: 9-4 (0.692) | 40427 avg over 7 home games
#
# Scraping USF (American Athletic Conference) → https://cfbstats.com/2021/team/651/index.html
# USF: 2-10 (0.167) | 33468 avg over 6 home games
#
# Scraping Boston College (Atlantic Coast Conference) → https://cfbstats.com/2021/team/67/index.html
# Boston College: 6-6 (0.5) | 34782 avg over 6 home games
#
# Scraping Clemson (Atlantic Coast Conference) → https://cfbstats.com/2021/team/147/index.html
# Clemson: 10-3 (0.769) | 79489 avg over 6 home games
#
# Scraping Duke (Atlantic Coast Conference) → https://cfbstats.com/2021/team/193/index.html
# Duke: 3-9 (0.25) | 15424 avg over 7 home games
#
# Scraping Florida State (Atlantic Coast Conference) → https://cfbstats.com/2021/team/234/index.html
# Florida State: 5-7 (0.417) | 58679 avg over 7 home games
#
# Scraping Georgia Tech (Atlantic Coast Conference) → https://cfbstats.com/2021/team/255/index.html
# Georgia Tech: 3-9 (0.25) | 37780 avg over 6 home games
#
# Scraping Louisville (Atlantic Coast Conference) → https://cfbstats.com/2021/team/367/index.html
# Louisville: 6-7 (0.462) | 43966 avg over 7 home games
#
# Scraping Miami (FL) (Atlantic Coast Conference) → https://cfbstats.com/2021/team/415/index.html
# Miami (FL): 7-5 (0.583) | 43698 avg over 7 home games
#
# Scraping NC State (Atlantic Coast Conference) → https://cfbstats.com/2021/team/490/index.html
# NC State: 9-3 (0.75) | 54523 avg over 7 home games
#
# Scraping North Carolina (Atlantic Coast Conference) → https://cfbstats.com/2021/team/457/index.html
# North Carolina: 6-7 (0.462) | 47947 avg over 7 home games
#
# Scraping Pittsburgh (Atlantic Coast Conference) → https://cfbstats.com/2021/team/545/index.html
# Pittsburgh: 11-3 (0.786) | 45365 avg over 7 home games
#
# Scraping Syracuse (Atlantic Coast Conference) → https://cfbstats.com/2021/team/688/index.html
# Syracuse: 5-7 (0.417) | 32461 avg over 7 home games
#
# Scraping Virginia (Atlantic Coast Conference) → https://cfbstats.com/2021/team/746/index.html
# Virginia: 6-6 (0.5) | 42439 avg over 7 home games
#
# Scraping Virginia Tech (Atlantic Coast Conference) → https://cfbstats.com/2021/team/742/index.html
# Virginia Tech: 6-7 (0.462) | 58729 avg over 7 home games
#
# Scraping Wake Forest (Atlantic Coast Conference) → https://cfbstats.com/2021/team/749/index.html
# Wake Forest: 11-3 (0.786) | 28721 avg over 6 home games
#
# Scraping Baylor (Big 12 Conference) → https://cfbstats.com/2021/team/51/index.html
# Baylor: 12-2 (0.857) | 44729 avg over 7 home games
#
# Scraping Iowa State (Big 12 Conference) → https://cfbstats.com/2021/team/311/index.html
# Iowa State: 7-6 (0.538) | 60704 avg over 6 home games
#
# Scraping Kansas (Big 12 Conference) → https://cfbstats.com/2021/team/328/index.html
# Kansas: 2-10 (0.167) | 26413 avg over 6 home games
#
# Scraping Kansas State (Big 12 Conference) → https://cfbstats.com/2021/team/327/index.html
# Kansas State: 8-5 (0.615) | 46368 avg over 7 home games
#
# Scraping Oklahoma (Big 12 Conference) → https://cfbstats.com/2021/team/522/index.html
# Oklahoma: 11-2 (0.846) | 77795 avg over 7 home games
#
# Scraping Oklahoma State (Big 12 Conference) → https://cfbstats.com/2021/team/521/index.html
# Oklahoma State: 12-2 (0.857) | 53012 avg over 7 home games
#
# Scraping TCU (Big 12 Conference) → https://cfbstats.com/2021/team/698/index.html
# TCU: 5-7 (0.417) | 39529 avg over 7 home games
#
# Scraping Texas (Big 12 Conference) → https://cfbstats.com/2021/team/703/index.html
# Texas: 5-7 (0.417) | 91938 avg over 6 home games
#
# Scraping Texas Tech (Big 12 Conference) → https://cfbstats.com/2021/team/700/index.html
# Texas Tech: 7-6 (0.538) | 52402 avg over 6 home games
#
# Scraping West Virginia (Big 12 Conference) → https://cfbstats.com/2021/team/768/index.html
# West Virginia: 6-7 (0.462) | 51583 avg over 6 home games
#
# Scraping Illinois (Big Ten Conference) → https://cfbstats.com/2021/team/301/index.html
# Illinois: 5-7 (0.417) | 35347 avg over 7 home games
#
# Scraping Indiana (Big Ten Conference) → https://cfbstats.com/2021/team/306/index.html
# Indiana: 2-10 (0.167) | 46925 avg over 6 home games
#
# Scraping Iowa (Big Ten Conference) → https://cfbstats.com/2021/team/312/index.html
# Iowa: 10-4 (0.714) | 66777 avg over 7 home games
#
# Scraping Maryland (Big Ten Conference) → https://cfbstats.com/2021/team/392/index.html
# Maryland: 7-6 (0.538) | 38069 avg over 7 home games
#
# Scraping Michigan (Big Ten Conference) → https://cfbstats.com/2021/team/418/index.html
# Michigan: 12-2 (0.857) | 108763 avg over 7 home games
#
# Scraping Michigan State (Big Ten Conference) → https://cfbstats.com/2021/team/416/index.html
# Michigan State: 11-2 (0.846) | 70135 avg over 6 home games
#
# Scraping Minnesota (Big Ten Conference) → https://cfbstats.com/2021/team/428/index.html
# Minnesota: 9-4 (0.692) | 46140 avg over 7 home games
#
# Scraping Nebraska (Big Ten Conference) → https://cfbstats.com/2021/team/463/index.html
# Nebraska: 3-9 (0.25) | 86173 avg over 7 home games
#
# Scraping Northwestern (Big Ten Conference) → https://cfbstats.com/2021/team/509/index.html
# Northwestern: 3-9 (0.25) | 30679 avg over 6 home games
#
# Scraping Ohio State (Big Ten Conference) → https://cfbstats.com/2021/team/518/index.html
# Ohio State: 11-2 (0.846) | 96756 avg over 7 home games
#
# Scraping Penn State (Big Ten Conference) → https://cfbstats.com/2021/team/539/index.html
# Penn State: 7-6 (0.538) | 106799 avg over 7 home games
#
# Scraping Purdue (Big Ten Conference) → https://cfbstats.com/2021/team/559/index.html
# Purdue: 9-4 (0.692) | 56332 avg over 6 home games
#
# Scraping Rutgers (Big Ten Conference) → https://cfbstats.com/2021/team/587/index.html
# Rutgers: 5-8 (0.385) | 44630 avg over 6 home games
#
# Scraping Wisconsin (Big Ten Conference) → https://cfbstats.com/2021/team/796/index.html
# Wisconsin: 9-4 (0.692) | 73466 avg over 7 home games
#
# Scraping Charlotte (Conference USA) → https://cfbstats.com/2021/team/458/index.html
# Charlotte: 5-7 (0.417) | 13292 avg over 6 home games
#
# Scraping FIU (Conference USA) → https://cfbstats.com/2021/team/231/index.html
# FIU: 1-11 (0.083) | N/A avg over 0 home games
#
# Scraping Florida Atlantic (Conference USA) → https://cfbstats.com/2021/team/229/index.html
# Florida Atlantic: 5-7 (0.417) | 18826 avg over 6 home games
#
# Scraping Louisiana Tech (Conference USA) → https://cfbstats.com/2021/team/366/index.html
# Louisiana Tech: 3-9 (0.25) | 14822 avg over 6 home games
#
# Scraping Marshall (Conference USA) → https://cfbstats.com/2021/team/388/index.html
# Marshall: 7-6 (0.538) | 21742 avg over 6 home games
#
# Scraping Middle Tennessee State (Conference USA) → https://cfbstats.com/2021/team/419/index.html
# Middle Tennessee State: 7-6 (0.538) | 12351 avg over 5 home games
#
# Scraping North Texas (Conference USA) → https://cfbstats.com/2021/team/497/index.html
# North Texas: 6-7 (0.462) | 16669 avg over 6 home games
#
# Scraping Old Dominion (Conference USA) → https://cfbstats.com/2021/team/523/index.html
# Old Dominion: 6-7 (0.462) | 15966 avg over 6 home games
#
# Scraping Rice (Conference USA) → https://cfbstats.com/2021/team/574/index.html
# Rice: 4-8 (0.333) | 18613 avg over 6 home games
#
# Scraping Southern Miss (Conference USA) → https://cfbstats.com/2021/team/664/index.html
# Southern Miss: 3-9 (0.25) | 23260 avg over 6 home games
#
# Scraping UAB (Conference USA) → https://cfbstats.com/2021/team/9/index.html
# UAB: 9-4 (0.692) | 25629 avg over 5 home games
#
# Scraping UTEP (Conference USA) → https://cfbstats.com/2021/team/704/index.html
# UTEP: 7-6 (0.538) | 16812 avg over 6 home games
#
# Scraping UTSA (Conference USA) → https://cfbstats.com/2021/team/706/index.html
# UTSA: 12-2 (0.857) | 26643 avg over 7 home games
#
# Scraping Western Kentucky (Conference USA) → https://cfbstats.com/2021/team/772/index.html
# Western Kentucky: 9-5 (0.643) | 16485 avg over 6 home games
#
# Scraping Army (FBS Independents) → https://cfbstats.com/2021/team/725/index.html
# Army: 9-4 (0.692) | 27263 avg over 6 home games
#
# Scraping BYU (FBS Independents) → https://cfbstats.com/2021/team/77/index.html
# BYU: 10-3 (0.769) | 61647 avg over 6 home games
#
# Scraping Connecticut (FBS Independents) → https://cfbstats.com/2021/team/164/index.html
# Connecticut: 1-11 (0.083) | 14686 avg over 6 home games
#
# Scraping Liberty (FBS Independents) → https://cfbstats.com/2021/team/355/index.html
# Liberty: 8-5 (0.615) | 17608 avg over 6 home games
#
# Scraping Massachusetts (FBS Independents) → https://cfbstats.com/2021/team/400/index.html
# Massachusetts: 1-11 (0.083) | 8994 avg over 6 home games
#
# Scraping New Mexico State (FBS Independents) → https://cfbstats.com/2021/team/472/index.html
# New Mexico State: 2-10 (0.167) | 11845 avg over 5 home games
#
# Scraping Notre Dame (FBS Independents) → https://cfbstats.com/2021/team/513/index.html
# Notre Dame: 11-2 (0.846) | 72817 avg over 7 home games
#
# Scraping Akron (Mid-American Conference) → https://cfbstats.com/2021/team/5/index.html
# Akron: 2-10 (0.167) | 10194 avg over 6 home games
#
# Scraping Ball State (Mid-American Conference) → https://cfbstats.com/2021/team/47/index.html
# Ball State: 6-7 (0.462) | 11530 avg over 6 home games
#
# Scraping Bowling Green (Mid-American Conference) → https://cfbstats.com/2021/team/71/index.html
# Bowling Green: 4-8 (0.333) | 15260 avg over 6 home games
#
# Scraping Buffalo (Mid-American Conference) → https://cfbstats.com/2021/team/86/index.html
# Buffalo: 4-8 (0.333) | 15129 avg over 6 home games
#
# Scraping Central Michigan (Mid-American Conference) → https://cfbstats.com/2021/team/129/index.html
# Central Michigan: 9-4 (0.692) | 14462 avg over 6 home games
#
# Scraping Eastern Michigan (Mid-American Conference) → https://cfbstats.com/2021/team/204/index.html
# Eastern Michigan: 7-6 (0.538) | 15091 avg over 6 home games
#
# Scraping Kent State (Mid-American Conference) → https://cfbstats.com/2021/team/331/index.html
# Kent State: 7-7 (0.5) | 12778 avg over 5 home games
#
# Scraping Miami (OH) (Mid-American Conference) → https://cfbstats.com/2021/team/414/index.html
# Miami (OH): 7-6 (0.538) | 11696 avg over 5 home games
#
# Scraping Northern Illinois (Mid-American Conference) → https://cfbstats.com/2021/team/503/index.html
# Northern Illinois: 9-5 (0.643) | 9058 avg over 6 home games
#
# Scraping Ohio (Mid-American Conference) → https://cfbstats.com/2021/team/519/index.html
# Ohio: 3-9 (0.25) | 17626 avg over 6 home games
#
# Scraping Toledo (Mid-American Conference) → https://cfbstats.com/2021/team/709/index.html
# Toledo: 7-6 (0.538) | 18436 avg over 6 home games
#
# Scraping Western Michigan (Mid-American Conference) → https://cfbstats.com/2021/team/774/index.html
# Western Michigan: 8-5 (0.615) | 13690 avg over 6 home games
#
# Scraping Air Force (Mountain West Conference) → https://cfbstats.com/2021/team/721/index.html
# Air Force: 10-3 (0.769) | 22831 avg over 6 home games
#
# Scraping Boise State (Mountain West Conference) → https://cfbstats.com/2021/team/66/index.html
# Boise State: 7-5 (0.583) | 34681 avg over 6 home games
#
# Scraping Colorado State (Mountain West Conference) → https://cfbstats.com/2021/team/156/index.html
# Colorado State: 3-9 (0.25) | 27096 avg over 6 home games
#
# Scraping Fresno State (Mountain West Conference) → https://cfbstats.com/2021/team/96/index.html
# Fresno State: 10-3 (0.769) | 33386 avg over 6 home games
#
# Scraping Hawaii (Mountain West Conference) → https://cfbstats.com/2021/team/277/index.html
# Hawaii: 6-7 (0.462) | 4605 avg over 3 home games
#
# Scraping Nevada (Mountain West Conference) → https://cfbstats.com/2021/team/466/index.html
# Nevada: 8-5 (0.615) | 21574 avg over 6 home games
#
# Scraping New Mexico (Mountain West Conference) → https://cfbstats.com/2021/team/473/index.html
# New Mexico: 3-9 (0.25) | 16332 avg over 6 home games
#
# Scraping San Diego State (Mountain West Conference) → https://cfbstats.com/2021/team/626/index.html
# San Diego State: 12-2 (0.857) | 10675 avg over 8 home games
#
# Scraping San Jose State (Mountain West Conference) → https://cfbstats.com/2021/team/630/index.html
# San Jose State: 5-7 (0.417) | 15447 avg over 6 home games
#
# Scraping UNLV (Mountain West Conference) → https://cfbstats.com/2021/team/465/index.html
# UNLV: 2-10 (0.167) | 22356 avg over 6 home games
#
# Scraping Utah State (Mountain West Conference) → https://cfbstats.com/2021/team/731/index.html
# Utah State: 11-3 (0.786) | 21378 avg over 6 home games
#
# Scraping Wyoming (Mountain West Conference) → https://cfbstats.com/2021/team/811/index.html
# Wyoming: 7-6 (0.538) | 21625 avg over 6 home games
#
# Scraping Arizona (Pac-12 Conference) → https://cfbstats.com/2021/team/29/index.html
# Arizona: 1-11 (0.083) | 34900 avg over 6 home games
#
# Scraping Arizona State (Pac-12 Conference) → https://cfbstats.com/2021/team/28/index.html
# Arizona State: 8-5 (0.615) | 47248 avg over 7 home games
#
# Scraping California (Pac-12 Conference) → https://cfbstats.com/2021/team/107/index.html
# California: 5-7 (0.417) | 37383 avg over 6 home games
#
# Scraping Colorado (Pac-12 Conference) → https://cfbstats.com/2021/team/157/index.html
# Colorado: 4-8 (0.333) | 46484 avg over 6 home games
#
# Scraping Oregon (Pac-12 Conference) → https://cfbstats.com/2021/team/529/index.html
# Oregon: 10-4 (0.714) | 49468 avg over 7 home games
#
# Scraping Oregon State (Pac-12 Conference) → https://cfbstats.com/2021/team/528/index.html
# Oregon State: 7-6 (0.538) | 30524 avg over 6 home games
#
# Scraping Stanford (Pac-12 Conference) → https://cfbstats.com/2021/team/674/index.html
# Stanford: 3-9 (0.25) | 35684 avg over 6 home games
#
# Scraping UCLA (Pac-12 Conference) → https://cfbstats.com/2021/team/110/index.html
# UCLA: 8-4 (0.667) | 45818 avg over 7 home games
#
# Scraping USC (Pac-12 Conference) → https://cfbstats.com/2021/team/657/index.html
# USC: 4-8 (0.333) | 56215 avg over 7 home games
#
# Scraping Utah (Pac-12 Conference) → https://cfbstats.com/2021/team/732/index.html
# Utah: 10-4 (0.714) | 51817 avg over 6 home games
#
# Scraping Washington (Pac-12 Conference) → https://cfbstats.com/2021/team/756/index.html
# Washington: 4-8 (0.333) | 61615 avg over 7 home games
#
# Scraping Washington State (Pac-12 Conference) → https://cfbstats.com/2021/team/754/index.html
# Washington State: 7-6 (0.538) | 23217 avg over 7 home games
#
# Scraping Alabama (Southeastern Conference) → https://cfbstats.com/2021/team/8/index.html
# Alabama: 13-2 (0.867) | 98720 avg over 7 home games
#
# Scraping Arkansas (Southeastern Conference) → https://cfbstats.com/2021/team/31/index.html
# Arkansas: 9-4 (0.692) | 65284 avg over 7 home games
#
# Scraping Auburn (Southeastern Conference) → https://cfbstats.com/2021/team/37/index.html
# Auburn: 6-7 (0.462) | 86146 avg over 7 home games
#
# Scraping Florida (Southeastern Conference) → https://cfbstats.com/2021/team/235/index.html
# Florida: 6-7 (0.462) | 85175 avg over 6 home games
#
# Scraping Georgia (Southeastern Conference) → https://cfbstats.com/2021/team/257/index.html
# Georgia: 14-1 (0.933) | 92746 avg over 6 home games
#
# Scraping Kentucky (Southeastern Conference) → https://cfbstats.com/2021/team/334/index.html
# Kentucky: 10-3 (0.769) | 56301 avg over 7 home games
#
# Scraping LSU (Southeastern Conference) → https://cfbstats.com/2021/team/365/index.html
# LSU: 6-7 (0.462) | 94808 avg over 7 home games
#
# Scraping Mississippi State (Southeastern Conference) → https://cfbstats.com/2021/team/430/index.html
# Mississippi State: 7-6 (0.538) | 49494 avg over 7 home games
#
# Scraping Missouri (Southeastern Conference) → https://cfbstats.com/2021/team/434/index.html
# Missouri: 6-7 (0.462) | 46516 avg over 7 home games
#
# Scraping Ole Miss (Southeastern Conference) → https://cfbstats.com/2021/team/433/index.html
# Ole Miss: 10-3 (0.769) | 56472 avg over 7 home games
#
# Scraping South Carolina (Southeastern Conference) → https://cfbstats.com/2021/team/648/index.html
# South Carolina: 7-6 (0.538) | 69734 avg over 7 home games
#
# Scraping Tennessee (Southeastern Conference) → https://cfbstats.com/2021/team/694/index.html
# Tennessee: 7-6 (0.538) | 86386 avg over 8 home games
#
# Scraping Texas A&M (Southeastern Conference) → https://cfbstats.com/2021/team/697/index.html
# Texas A&M: 8-4 (0.667) | 102883 avg over 7 home games
#
# Scraping Vanderbilt (Southeastern Conference) → https://cfbstats.com/2021/team/736/index.html
# Vanderbilt: 2-10 (0.167) | 23458 avg over 7 home games
#
# Scraping Appalachian State (Sun Belt Conference) → https://cfbstats.com/2021/team/27/index.html
# Appalachian State: 10-4 (0.714) | 29389 avg over 6 home games
#
# Scraping Arkansas State (Sun Belt Conference) → https://cfbstats.com/2021/team/30/index.html
# Arkansas State: 2-10 (0.167) | 11211 avg over 6 home games
#
# Scraping Coastal Carolina (Sun Belt Conference) → https://cfbstats.com/2021/team/149/index.html
# Coastal Carolina: 11-2 (0.846) | 15241 avg over 7 home games
#
# Scraping Georgia Southern (Sun Belt Conference) → https://cfbstats.com/2021/team/253/index.html
# Georgia Southern: 3-9 (0.25) | 16761 avg over 6 home games
#
# Scraping Georgia State (Sun Belt Conference) → https://cfbstats.com/2021/team/254/index.html
# Georgia State: 8-5 (0.615) | 15074 avg over 6 home games
#
# Scraping Louisiana (Sun Belt Conference) → https://cfbstats.com/2021/team/671/index.html
# Louisiana: 13-1 (0.929) | 22493 avg over 7 home games
#
# Scraping Louisiana-Monroe (Sun Belt Conference) → https://cfbstats.com/2021/team/498/index.html
# Louisiana-Monroe: 4-8 (0.333) | 13280 avg over 6 home games
#
# Scraping South Alabama (Sun Belt Conference) → https://cfbstats.com/2021/team/646/index.html
# South Alabama: 5-7 (0.417) | 16083 avg over 6 home games
#
# Scraping Texas State (Sun Belt Conference) → https://cfbstats.com/2021/team/670/index.html
# Texas State: 4-8 (0.333) | 17686 avg over 6 home games
#
# Scraping Troy (Sun Belt Conference) → https://cfbstats.com/2021/team/716/index.html
# Troy: 5-7 (0.417) | 23668 avg over 6 home games
#
#
# Scraping complete! Saved as 'cfbstats_conference_attendance.csv'
# Total teams with data: 130

# %% [markdown]
# ##### Remapping Conference Names

# %%
#Loads existing dataset that was just scraped
attendance_df = pd.read_csv("cfbstats_conference_attendance.csv")

#Cleans up conference names
attendance_df["conference"] = attendance_df["conference"].replace({
    "Big Ten Conference": "Big Ten",
    "Southeastern Conference": "SEC",
    "Pac-12 Conference": "Pac-12",
    "Atlantic Coast Conference": "ACC",
    "Big 12 Conference": "Big 12",
    "American Athletic Conference": "AAC",
    "Conference USA": "C-USA",
    "Mid-American Conference": "MAC",
    "Mountain West Conference": "Mountain West",
    "Sun Belt Conference": "Sun Belt",
    "FBS Independents": "Independent"
})

display(attendance_df)
# Out:
#      team_id          team_name     conference  wins  losses  win_pct  \
# 0        418           Michigan        Big Ten    12       2    0.857
# 1        539         Penn State        Big Ten     7       6    0.538
# 2        697          Texas A&M            SEC     8       4    0.667
# 3          8            Alabama            SEC    13       2    0.867
# 4        518         Ohio State        Big Ten    11       2    0.846
# ..       ...                ...            ...   ...     ...      ...
# 125        5              Akron            MAC     2      10    0.167
# 126      503  Northern Illinois            MAC     9       5    0.643
# 127      400      Massachusetts    Independent     1      11    0.083
# 128      277             Hawaii  Mountain West     6       7    0.462
# 129      231                FIU          C-USA     1      11    0.083
#
#      avg_home_attendance  num_home_games
# 0               108763.0               7
# 1               106799.0               7
# 2               102883.0               7
# 3                98720.0               7
# 4                96756.0               7
# ..                   ...             ...
# 125              10194.0               6
# 126               9058.0               6
# 127               8994.0               6
# 128               4605.0               3
# 129                  NaN               0
#
# [130 rows x 8 columns]

# %%
#Loads the CFBD metadata file
cfbd_df = pd.read_csv("cfbd.csv")

#Renames some columns
cfbd_df.rename(columns={'School': 'team_name','Location City':'city', 'Id':'Logo Id', 'Location Name':'stadium'}, inplace=True)

#Looks for teams that were scraped that are not in the CFBD set due to different names
missing_in_cfbd = sorted(set(attendance_df["team_name"].unique()) - set(cfbd_df["team_name"].unique()))
if missing_in_cfbd:
    print("Teams in attendance_df not found in cfbd_df:")
    print(missing_in_cfbd)
# Out:
# Teams in attendance_df not found in cfbd_df:
# ['Appalachian State', 'Connecticut', 'FIU', 'Hawaii', 'Louisiana-Monroe', 'Miami (FL)', 'Middle Tennessee State', 'San Jose State', 'USF']

# %%
#Fix common mismatches so merge works
cfbd_df["team_name"] = cfbd_df["team_name"].replace({
    "App State": "Appalachian State",
    "UConn": "Connecticut",
    "Florida International": "FIU",
    "Hawai'i": "Hawaii",
    "UL Monroe": "Louisiana-Monroe",
    "Miami": "Miami (FL)",
    "Middle Tennessee": "Middle Tennessee State",
    "San José State": "San Jose State",
    "South Florida": "USF"
})

#Double checks for any mismatches
missing_in_cfbd = sorted(set(attendance_df["team_name"].unique()) - set(cfbd_df["team_name"].unique()))
if missing_in_cfbd:
    print("Teams in attendance_df not found in cfbd_df:")
    print(missing_in_cfbd)
else:
    print("All team names match")
# Out:
# All team names match

# %%
#Picks columns to keep from CFBD dataset
cfbd_columns_to_keep = [
    "team_name",    
    "Logo Id",                  
    "Color",           
    "AlternateColor",          
    "stadium",
    "city",
    "Location State",
    "Location Latitude",
    "Location Longitude",
    "Location Capacity"
]

#Keeps only those columns (ignore missing ones safely)
cfbd_trimmed = cfbd_df.loc[:, [col for col in cfbd_columns_to_keep if col in cfbd_df.columns]].copy()

#Perform the merge, only keeping teams that appear in attendance_df
merged_df = pd.merge(
    attendance_df,
    cfbd_trimmed,
    on="team_name",
    how="inner"
)


display(merged_df)
merged_df.to_csv("cfbstats_cfbd_merged.csv", index=False)
print("\nSaved as 'cfbstats_cfbd_merged.csv'")
# Out:
#      team_id          team_name     conference  wins  losses  win_pct  \
# 0        418           Michigan        Big Ten    12       2    0.857
# 1        539         Penn State        Big Ten     7       6    0.538
# 2        697          Texas A&M            SEC     8       4    0.667
# 3          8            Alabama            SEC    13       2    0.867
# 4        518         Ohio State        Big Ten    11       2    0.846
# ..       ...                ...            ...   ...     ...      ...
# 125        5              Akron            MAC     2      10    0.167
# 126      503  Northern Illinois            MAC     9       5    0.643
# 127      400      Massachusetts    Independent     1      11    0.083
# 128      277             Hawaii  Mountain West     6       7    0.462
# 129      231                FIU          C-USA     1      11    0.083
#
#      avg_home_attendance  num_home_games  Logo Id    Color AlternateColor  \
# 0               108763.0               7      130  #00274c        #ffcb05
# 1               106799.0               7      213  #041E42        #FFFFFF
# 2               102883.0               7      245  #500000        #ffffff
# 3                98720.0               7      333  #9e1632        #ffffff
# 4                96756.0               7      194  #ce1141        #505056
# ..                   ...             ...      ...      ...            ...
# 125              10194.0               6     2006  #00285e        #84754e
# 126               9058.0               6     2459  #F1122C        #cc0000
# 127               8994.0               6      113  #971B2F        #B1B3B3
# 128               4605.0               3       62  #003420        #ffffff
# 129                  NaN               0     2229  #001538        #c5960c
#
#                 city Location State  Location Latitude  Location Longitude  \
# 0          Ann Arbor             MI          42.265836          -83.748696
# 1    University Park             PA          40.812196          -77.856102
# 2    College Station             TX          30.609889          -96.340383
# 3         Tuscaloosa             AL          33.208275          -87.550384
# 4           Columbus             OH          40.001645          -83.019727
# ..               ...            ...                ...                 ...
# 125            Akron             OH          41.072553          -81.508341
# 126           DeKalb             IL          41.933959          -88.777836
# 127           Hadley             MA          42.377324          -72.536059
# 128         Honolulu             HI          21.294294         -157.819338
# 129            Miami             FL          25.760000          -80.380000
#
#      Location Capacity
# 0               107601
# 1               106572
# 2               102733
# 3               101821
# 4               102780
# ..                 ...
# 125              30000
# 126              23595
# 127              17000
# 128               9000
# 129              20000
#
# [130 rows x 16 columns]
# Saved as 'cfb_attendance_with_locations.csv'

# %% [markdown]
# ### Educational Data API Scraping

# %%
#Reads url and gets results from IPEDS directory
url = "https://educationdata.urban.org/api/v1/college-university/ipeds/directory/2021/"
response = urlopen(url)
data = loads(response.read())
print("Keys:", data.keys())
print("Number of schools:", len(data["results"]))

#Puts results into dataframe
df_direct = pd.DataFrame(data["results"])

#Keeps specific columns
keep_cols = ["unitid", "inst_name", "state_abbr", "city", "county_name"]
df_direct = df_direct[keep_cols]

df_direct.head()
# Out:
# Keys: dict_keys(['count', 'next', 'previous', 'results'])
# Number of schools: 6289
#    unitid                            inst_name state_abbr        city  \
# 0  100654             Alabama A & M University         AL      Normal
# 1  100663  University of Alabama at Birmingham         AL  Birmingham
# 2  100690                   Amridge University         AL  Montgomery
# 3  100706  University of Alabama in Huntsville         AL  Huntsville
# 4  100724             Alabama State University         AL  Montgomery
#
#          county_name
# 0     Madison County
# 1   Jefferson County
# 2  Montgomery County
# 3     Madison County
# 4  Montgomery County

# %%
#Reads url and gets results from IPEDS institutional characterisitcs
url = "https://educationdata.urban.org/api/v1/college-university/eada/institutional-characteristics/2021/"
response = urlopen(url)
data = loads(response.read())
print("Keys:", data.keys())
print("Number of schools:", len(data["results"]))

#Puts results into dataframe
df_ath = pd.DataFrame(data["results"])

#Keeps specific columns
keep_cols = ["unitid", "enrollment_men", "enrollment_women", "enrollment_total", "ath_classification_code"]
df_ath = df_ath[keep_cols]

df_ath.head()
# Out:
# Keys: dict_keys(['count', 'next', 'previous', 'results'])
# Number of schools: 2028
#    unitid  enrollment_men  enrollment_women  enrollment_total  \
# 0  800001            5723              6570             12293
# 1  100654            1823              2706              4529
# 2  100663            3924              6442             10366
# 3  100706            3726              2491              6217
# 4  100724            1053              2002              3055
#
#    ath_classification_code
# 0                        4
# 1                        2
# 2                        1
# 3                        5
# 4                        2

# %%
merged = (
    df_direct
    .merge(df_ath, on="unitid", how="left")
)

merged = merged.drop(columns=["unitid"])

merged.head()
# Out:
#                              inst_name state_abbr        city  \
# 0             Alabama A & M University         AL      Normal
# 1  University of Alabama at Birmingham         AL  Birmingham
# 2                   Amridge University         AL  Montgomery
# 3  University of Alabama in Huntsville         AL  Huntsville
# 4             Alabama State University         AL  Montgomery
#
#          county_name  enrollment_men  enrollment_women  enrollment_total  \
# 0     Madison County          1823.0            2706.0            4529.0
# 1   Jefferson County          3924.0            6442.0           10366.0
# 2  Montgomery County             NaN               NaN               NaN
# 3     Madison County          3726.0            2491.0            6217.0
# 4  Montgomery County          1053.0            2002.0            3055.0
#
#    ath_classification_code
# 0                      2.0
# 1                      1.0
# 2                      NaN
# 3                      5.0
# 4                      2.0

# %%
merged.to_csv("ipeds_directory_plus_enroll.csv", index=False)
print("Saved: ipeds_directory_plus_enroll.csv")
# Out:
# Saved: ipeds_directory_plus_enroll.csv

# %% [markdown]
# ### Merge CFBStats and Educational API

# %%
#Reads in CSV files
cfb = pd.read_csv("cfbstats_cfbd_merged.csv")
ipeds = pd.read_csv("ipeds_directory_plus_enroll.csv")

# %%
#Function that cleans both city columns to make sure they match
def clean_city(x):
    return (
        str(x).lower()
              .replace(".", "")
              .replace(",", "")
              .strip()
    )

#Applies the function to both city columns
cfb["city_clean"] = cfb["city"].apply(clean_city)
ipeds["city_clean"] = ipeds["city"].apply(clean_city)

#Filters down schools who participate in D1 athletics to make merging easier
ipeds_d1 = ipeds[ipeds["ath_classification_code"] == 1]

# %%
#Merges both datasets on the 'city_clean' column
merged_city = pd.merge(
    cfb,
    ipeds_d1,
    on="city_clean",
    how="left"
)

#Drops the 'city_clean' column
merged_city.drop(columns=["city_clean"], inplace=True)

#Sorts the data frame
merged_city_sorted = merged_city.sort_values(
    by=["team_name", "enrollment_total"], 
    ascending=[True, False]
)

#Drops duplicate team_name
merged_on_city = merged_city_sorted.drop_duplicates(subset=["team_name"], keep="first")

print(merged_on_city.shape)
merged_on_city.head()
# Out:
# (130, 24)
#      team_id          team_name     conference  wins  losses  win_pct  \
# 88       721          Air Force  Mountain West    10       3    0.769
# 136        5              Akron            MAC     2      10    0.167
# 3          8            Alabama            SEC    13       2    0.867
# 74        27  Appalachian State       Sun Belt    10       4    0.714
# 64        29            Arizona         Pac-12     1      11    0.083
#
#      avg_home_attendance  num_home_games  Logo Id    Color  ...  \
# 88               22831.0               6     2005  #004a7b  ...
# 136              10194.0               6     2006  #00285e  ...
# 3                98720.0               7      333  #9e1632  ...
# 74               29389.0               6     2026  #ffcc00  ...
# 64               34900.0               6       12  #0c234b  ...
#
#     Location Longitude Location Capacity                        inst_name  \
# 88         -104.843616             46692                              NaN
# 136         -81.508341             30000  University of Akron Main Campus
# 3           -87.550384            101821        The University of Alabama
# 74          -81.685428             30000     Appalachian State University
# 64         -110.948868             50782            University of Arizona
#
#      state_abbr      city_y        county_name enrollment_men  \
# 88          NaN         NaN                NaN            NaN
# 136          OH       Akron      Summit County         4940.0
# 3            AL  Tuscaloosa  Tuscaloosa County        12366.0
# 74           NC       Boone     Watauga County         7505.0
# 64           AZ      Tucson        Pima County        12749.0
#
#     enrollment_women enrollment_total ath_classification_code
# 88               NaN              NaN                     NaN
# 136           4327.0           9267.0                     1.0
# 3            15708.0          28074.0                     1.0
# 74            9876.0          17381.0                     1.0
# 64           16691.0          29440.0                     1.0
#
# [5 rows x 24 columns]

# %%
#Changes names of problem schools to match
ipeds_to_cfb = {
    "United States Air Force Academy": "Air Force",
    "United States Military Academy": "Army",
    "United States Naval Academy": "Navy",
    "University of Connecticut": "Connecticut",
    "University of Miami": "Miami (FL)",
    "Mississippi State University": "Mississippi State",
    "Rice University": "Rice",
    "University of California-Los Angeles": "UCLA",
    "University of Southern California": "USC",
    "University at Buffalo": "Buffalo",
    "Georgia Institute of Technology-Main Campus": "Georgia Tech",
    "University of Mississippi": "Ole Miss",
    "Rutgers University-New Brunswick": "Rutgers",
    "Southern Methodist University": "SMU"
}
ipeds_d1["team_name"] = ipeds_d1["inst_name"].replace(ipeds_to_cfb)
# Out:
# C:\Users\caede\AppData\Local\Temp\ipykernel_29628\2271561773.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipeds_d1["team_name"] = ipeds_d1["inst_name"].replace(ipeds_to_cfb)

# %%
#Creates a new list of rows that did not merge properly
problem_list = list(ipeds_to_cfb.values())

matched = merged_on_city[~merged_on_city["team_name"].isin(problem_list)]
ipeds_for_fix = ipeds_d1[ipeds_d1["team_name"].isin(problem_list)]
cfb_for_fix = cfb[cfb["team_name"].isin(problem_list)]

# %%
#Merges rows that used different cities or share a city with another school on other features
fixed_merge = pd.merge(
    cfb_for_fix,
    ipeds_for_fix,
    on="team_name",
    how="left"
)

final_merged = pd.concat([matched, fixed_merge], ignore_index=True)
final_merged = final_merged.drop_duplicates(subset=["team_name"], keep="first")

#Drops unnecessary and extra columns created during joins
final_merged.drop(columns=["inst_name", "city_clean", "Location State", "county_name", "city_y", "city_clean_x", "city_clean_y", "ath_classification_code", "team_id"], errors="ignore", inplace=True)

#Rename city_x to city
if "city_x" in final_merged.columns:
    final_merged.rename(columns={"city_x": "city"}, inplace=True)

#Drop schools with no information
drop_list = [
    "Army", "Navy", "Air Force", 
    "Massachusetts"
]
final_merged = final_merged[~final_merged["team_name"].isin(drop_list)]

# %%
#Converts all column names to snake case
final_merged.columns = (
    final_merged.columns.str.strip()              
                      .str.lower()      
                      .str.replace(" ", "_")  
                      .str.replace("-", "_") 
                      .str.replace("/", "_")  
                      .str.replace(r"[^0-9a-zA-Z_]", "", regex=True)
)

# %%
#Final dataset
final_merged.to_csv("final_college_cleaned.csv", index=False)
print("Saved: final_college_cleaned.csv")
# Out:
# Saved: final_college_cleaned.csv
